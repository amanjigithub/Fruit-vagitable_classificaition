# %% [markdown]
# <a href="https://colab.research.google.com/github/amanjigithub/Fruit-vagitable_classificaition/blob/main/TestingModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import numpy as np
# import tensorflow as tf
# from keras.preprocessing.image import ImageDataGenerator
# import matplotlib.pyplot as plt

import numpy as np
import tensorflow as tf
#Instead of using 'from keras.preprocessing.image import ImageDataGenerator'
#Use 'from tensorflow.keras.preprocessing.image import ImageDataGenerator'
from tensorflow.keras.preprocessing.image import ImageDataGenerator # Import from tensorflow.keras instead
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f42d5866b8ee> in <cell line: 0>()
#       5
#       6 import numpy as np
# ----> 7 import tensorflow as tf
#       8 #Instead of using 'from keras.preprocessing.image import ImageDataGenerator'
#       9 #Use 'from tensorflow.keras.preprocessing.image import ImageDataGenerator'
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/__init__.py in <module>
#     465     importlib.import_module("tf_keras.src.optimizers")
#     466   else:
# --> 467     importlib.import_module("keras.src.optimizers")
#     468 except (ImportError, AttributeError):
#     469   pass
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# ...

# %%
# Connect to drive
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ##Test set Image Processing

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/fruit_recognition/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)

# %% [markdown]
# ## Loading Model

# %%
# cnn = tf.keras.models.load_model('/content/drive/MyDrive/fruitmodal/trained_model.h5')
cnn = tf.keras.models.load_model('/content/drive/MyDrive/fruit_recognition/train')

# %% [markdown]
# ##Visualising and Performing Prediction on Single image

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/fruit_recognition/test/apple/Image_1.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ##Testing Model

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)

# %%
print(predictions)

# %%
# test_set.class_names

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)

# %%
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Single image Prediction
print("It's a {}".format(test_set.class_names[result_index]))
